# %% [markdown]
# #                                            Movie tickets Booking

# %% [markdown]
# - Ashore
# - Santhosh
# - Ruba kumar
# - Rohit
# - Karthik

# %%
global f
f = 0
 
#this t_movie function is used to select movie name
def city():
    print("Hi welcome to movie ticket booking: ")
    print("where you want to watch movie?:")
    print("1.Mumbai")
    print("2.Chennai")
    print("3.Bangalore ")
    place = int(input("choose your option: "))
    if place == 1:
        center()
    elif place == 2:
        center()
    elif place == 3:
        center()
    else:
        print("wrong choice")
        
def center():
    print("which theater do you wish to see movie? ")
    print("1.pvr")
    print("2.IMax")
    print("3.Ags")
    print("4.back")
    a = int(input("choose your option: "))
    movie(a)
    return 0

def movie(theater):
    if theater == 1:
        t_movie()
    elif theater == 2:
        t_movie()
    elif theater == 3:
        t_movie()
    elif theater == 4:
        city()
    else:
        print("wrong choice")
        
def t_movie():
    global f
    f = f+1
    print("which movie do you want to watch?")
    print("1.RRR ")
    print("2.KGF 2 ")
    print("3.VIKRAM")
    print("4.back")
    movie = int(input("choose your movie: "))
    if movie == 4:
        center()
        theater()
        return 0
    if f == 1:
        theater()
 
# this theater function used to select screen
def theater():
    print("which screen do you want to watch movie: ")
    print("1.SCREEN 1")
    print("2.SCREEN 2")
    print("3.SCREEN 3")
    a = int(input("choose your screen: "))
    ticket = int(input("number of ticket do you want?: "))
    timing(a)
 
# this timing function used to select timing for movie
def timing(a):
    time1 = {
        "1": "10.00 AM-1.00 PM",
        "2": "1.10 PM-4.10 PM",
        "3": "4.20 PM-7.20 PM",
        "4": "7.30 PM-10.30 PM"
    }
    time2 = {
        "1": "10.15 AM-1.15 PM",
        "2": "1.25 PM-4.25 PM",
        "3": "4.35 PM-7.35 PM",
        "4": "7.45 PM-10.45 PM"
    }
    time3 = {
        "1": "10.30 AM-1.30 PM",
        "2": "1.40 PM-4.40 PM",
        "3": "4.50 PM-7.50 PM",
        "4": "8.00 PM-10.45 PM"
    }
    if a == 1:
        print("choose your time:")
        print(time1)
        t = input("select your time:")
        x = time1[t]
        print("successful!, enjoy movie at "+x)
    elif a == 2:
        print("choose your time:")
        print(time2)
        t = input("select your time:")
        x = time2[t]
        print("successful!, enjoy movie at "+x)
    elif a == 3:
        print("choose your time:")
        print(time3)
        t = input("select your time:")
        x = time3[t]
        print("successful!, enjoy movie at "+x)
    return 0
 
city()
# Out:
# Hi welcome to movie ticket booking:
# where you want to watch movie?:
# 1.Mumbai
# 2.Chennai
# 3.Bangalore
# choose your option: 2
# which theater do you wish to see movie?
# 1.pvr
# 2.IMax
# 3.Ags
# 4.back
# choose your option: 1
# which movie do you want to watch?
# 1.RRR
# 2.KGF 2
# 3.VIKRAM
# 4.back
# choose your movie: 3
# which screen do you want to watch movie:
# 1.SCREEN 1
# 2.SCREEN 2
# 3.SCREEN 3
# choose your screen: 3
# number of ticket do you want?: 10
# choose your time:
# {'1': '10.30 AM-1.30 PM', '2': '1.40 PM-4.40 PM', '3': '4.50 PM-7.50 PM', '4': '8.00 PM-10.45 PM'}
# select your time:4
# successful!, enjoy movie at 8.00 PM-10.45 PM
